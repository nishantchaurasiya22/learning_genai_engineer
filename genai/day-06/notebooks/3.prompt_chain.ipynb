# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
prompts=[
    {"role":"system","content":"You are a translator and you are translate in hindi not explain only convert english sentence in hindi "},
    {"role":"user","content":"what is array in javascript"}
]

res=llm.invoke(prompts)
print(res.content)

# %% [markdown]
# ##### Prompt Templates-Dynamic Prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

# %%
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
prompts=ChatPromptTemplate.from_messages([
    {"role":"system","content":"You are a translator, translate input in {language}"},
    {"role":"user","content":"{query}"}
])

# %%
final_prompt=prompts.format_messages(language="hinglish",query="I Love python and javascript")

# %%
res=llm.invoke(final_prompt)
print(res.content)

# %% [markdown]
# ##### Chaning in Langchain

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")
output=StrOutputParser()

# %%
prompts=ChatPromptTemplate.from_messages([
    {"role":"system","content":"You are a translator,translate input in {language}"},
    {"role":"user","content":"{query}"}
])

# %%
# res=llm.invoke(prompts.invoke({"language":"hindi","query":"Understand chaining in langchain"}))
# print(res.content)

# %%
chains = prompts | llm | output
chains

# %%
res=chains.invoke({"language":"hindi","query":"Understand chaining in langchain"})
print(res)
# Out:
# LangChain में "चेनिंग" (Chaining) का मतलब है कई अलग-अलग घटकों (components) को एक साथ जोड़ना ताकि वे एक क्रम में (sequentially) या एक विशिष्ट तरीके से काम कर सकें। यह एक वर्कफ़्लो (workflow) या पाइपलाइन (pipeline) की तरह है जहाँ एक घटक का आउटपुट अगले घटक का इनपुट बन जाता है।
#
# इसे आसान शब्दों में समझते हैं:
#
# **चेन क्या है? (What is a Chain?)**
# LangChain में, चेन एक ऐसा तरीका है जिससे आप अलग-अलग हिस्सों (जैसे कि एक प्रॉम्प्ट टेम्पलेट, एक LLM, एक टूल, या दूसरी चेन) को जोड़कर एक बड़ा और जटिल काम करवा सकते हैं। यह आपको मल्टी-स्टेप (कई चरणों वाली) प्रक्रियाओं को बनाने की सुविधा देता है।
#
# **चेन का उपयोग क्यों करें? (Why use Chains?)**
# अक्सर, आपको केवल एक LLM (लार्ज लैंग्वेज मॉडल) कॉल से ज़्यादा की ज़रूरत होती है। उदाहरण के लिए:
# 1.  आपको LLM को भेजने से पहले इनपुट डेटा को प्री-प्रोसेस (pre-process) करना पड़ सकता है।
# 2.  आपको LLM के आउटपुट को पोस्ट-प्रोसेस (post-process) करना पड़ सकता है।
# 3.  आपको एक ही कार्य को पूरा करने के लिए कई LLM कॉल्स को एक साथ जोड़ना पड़ सकता है।
# ...
