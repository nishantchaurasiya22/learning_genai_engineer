# %% [markdown]
# ##### Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
res=llm.invoke("what is chagpt")
print(res.content)
