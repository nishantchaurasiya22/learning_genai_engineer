# %% [markdown]
# ##### Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ##### Connect With Google Gemini LLM

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
res=llm.invoke("What is fastapi")
print(res.content)

# %% [markdown]
# ##### Connect With Groq LLM

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(model="llama-3.3-70b-versatile")

# %%
res=llm.invoke("sqlqlchemy eork in fastapi")
print(res.content)

# %% [markdown]
# ##### Static Prompt

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
prompts=[
    ("system","You are a senior python backend developer"),
    ("user","sqlalchemy  how works?")
]
res=llm.invoke(prompts)
print(res.content)
