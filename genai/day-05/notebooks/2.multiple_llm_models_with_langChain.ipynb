# %% [markdown]
# ##### Load Env Variable

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ##### Connect with Google Gemini Model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
res=llm.invoke("What is fastapi")
print(res.content)

# %% [markdown]
# ##### Connect With Groq Model

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(model="llama-3.3-70b-versatile")

# %%
res=llm.invoke("what is postgres")
print(res.content)

# %% [markdown]
# ##### Static Prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
prompts=[
    ("system","You are a senior python backend developer"),
    ("user","sqlalchemy  how works?")
]
res=llm.invoke(prompts)
print(res.content)
# Out:
# SQLAlchemy is a comprehensive and powerful SQL toolkit and Object-Relational Mapper (ORM) for Python. It provides a full suite of well-known persistence patterns, designed for efficient and high-performing database access, with a focus on enterprise-level usage.
#
# At its core, SQLAlchemy works by providing a layer of abstraction between your Python application and your database. It handles the complexities of SQL syntax, database connections, and object-relational mapping, allowing you to interact with your database using Python objects and methods.
#
# Let's break down how it works, component by component:
#
# ---
#
# ### 1. The "Why": Bridging the Impedance Mismatch
#
# Databases (relational model) and object-oriented programming languages (object model) have fundamental differences in how they represent data. This is known as the "object-relational impedance mismatch."
#
# *   **Relational Databases:** Store data in tables with rows and columns, designed for efficient querying and data integrity.
# *   **Object-Oriented Languages:** Represent data as objects with attributes and methods, designed for encapsulation, inheritance, and polymorphism.
#
# SQLAlchemy's primary goal is to bridge this gap, allowing developers to work with database data using familiar Python objects while still leveraging the power and efficiency of relational databases.
#
# ---
#
# ### 2. High-Level Overview: Core vs. ORM
#
# SQLAlchemy is often thought of as an ORM, but it's actually two distinct (though integrated) components:
#
# 1.  **SQLAlchemy Core (SQL Expression Language):** This is the foundation. It provides a programmatic way to construct SQL queries using Python objects, without needing to write raw SQL strings. It's database-agnostic and powerful for building complex, optimized queries.
# 2.  **SQLAlchemy ORM (Object Relational Mapper):** Built on top of Core, the ORM maps Python classes to database tables and instances of those classes to rows in those tables. It allows you to interact with your database using Python objects, handling the conversion of object operations into SQL statements and vice-versa.
#
# You can use Core and ORM independently or together, depending on your needs.
#
# ---
#
# ### 3. Core Components: The Building Blocks
#
# #### a. Engine
#
# The `Engine` is the starting point for any SQLAlchemy application. It's responsible for:
# *   **Connecting to the database:** It uses a database URL (e.g., `postgresql://user:pass@host:port/dbname`) to establish a connection.
# *   **Dialects:** It loads the appropriate "dialect" for your specific database (e.g., PostgreSQL, MySQL, SQLite, Oracle). The dialect translates SQLAlchemy's generic SQL expressions into the specific SQL syntax of your database.
# *   **Connection Pooling:** Manages a pool of database connections to efficiently reuse them, reducing overhead.
#
# **How it works:** You create an `Engine` once per database using `create_engine()`.
#
# ```python
# from sqlalchemy import create_engine
# engine = create_engine('sqlite:///mydatabase.db', echo=True) # echo=True logs all SQL
# ```
#
# #### b. Connection
#
# While the `Engine` manages *how* to connect, a `Connection` is an actual, active link to the database.
# *   You obtain a `Connection` from the `Engine`.
# *   SQLAlchemy Core uses `Connection` objects to execute SQL statements directly.
#
# ```python
# with engine.connect() as connection:
#     result = connection.execute(text("SELECT 1"))
#     print(result.scalar())
# ```
#
# #### c. Metadata and Table
#
# These components define your database schema in Python.
# *   **`MetaData`:** A container object that holds information about your database schema, including all the tables, columns, constraints, etc.
# *   **`Table`:** Represents a single database table. You define its name, `MetaData` object, and a list of `Column` objects.
# *   **`Column`:** Defines a column in a `Table`, including its name, data type (e.g., `Integer`, `String`, `DateTime`), primary key status, foreign key constraints, etc.
#
# **How it works:** You define your tables using `Table` and `Column` objects, associating them with a `MetaData` instance.
#
# ```python
# from sqlalchemy import MetaData, Table, Column, Integer, String, ForeignKey
# metadata_obj = MetaData()
# users_table = Table(
#     "users",
#     metadata_obj,
#     Column("id", Integer, primary_key=True),
#     Column("name", String(30), nullable=False),
#     Column("email", String, unique=True)
# )
# addresses_table = Table(
#     "addresses",
#     metadata_obj,
#     Column("id", Integer, primary_key=True),
#     Column("user_id", Integer, ForeignKey("users.id")),
#     Column("street", String)
# )
# # To create tables in the database:
# # metadata_obj.create_all(engine)
# ```
#
# #### d. SQL Expression Language (Core)
#
# This is SQLAlchemy's way of building SQL statements programmatically using Python objects. Instead of writing `SELECT name FROM users WHERE id = 1;`, you construct an equivalent Python object structure.
#
# **How it works:**
# *   It provides functions like `select()`, `insert()`, `update()`, `delete()`.
# *   You use Python operators (`==`, `!=`, `in_`, `like`) to build `WHERE` clauses.
# *   You use methods like `.order_by()`, `.group_by()`, `.join()` for more complex queries.
#
# ```python
# from sqlalchemy import select, insert, text
#
# # Insert
# with engine.connect() as connection:
#     connection.execute(
#         insert(users_table).values(name="Alice", email="alice@example.com")
#     )
#     connection.commit()
#
# # Select
# with engine.connect() as connection:
#     stmt = select(users_table.c.name, users_table.c.email).where(users_table.c.name == "Alice")
#     result = connection.execute(stmt)
#     for row in result:
#         print(f"Name: {row.name}, Email: {row.email}")
# ```
#
# ---
#
# ### 4. ORM Components: Object-Relational Mapping
#
# The ORM builds on Core to map Python classes directly to database tables.
#
# #### a. Declarative Base / Mapped Classes
#
# This is how you define your Python classes that correspond to database tables.
# *   **`declarative_base()`:** A factory function that creates a base class for your ORM models.
# *   **Mapped Classes:** Python classes that inherit from this base. You define attributes on these classes that correspond to columns in the database table.
#
# **How it works (Modern SQLAlchemy 2.0 style):**
# You define your Python classes, inheriting from a `Base` object. You use `Mapped` and `mapped_column` to define attributes that map to database columns, and `relationship()` to define relationships between models.
#
# ```python
# from sqlalchemy.orm import declarative_base, Mapped, mapped_column, relationship
# from sqlalchemy import String, Integer, ForeignKey
# from typing import List
#
# Base = declarative_base()
#
# class User(Base):
#     __tablename__ = "users"
#     id: Mapped[int] = mapped_column(primary_key=True)
#     name: Mapped[str] = mapped_column(String(30))
#     email: Mapped[str] = mapped_column(String, unique=True)
#
#     addresses: Mapped[List["Address"]] = relationship(back_populates="user")
#
#     def __repr__(self):
#         return f"<User(id={self.id}, name='{self.name}')>"
#
# class Address(Base):
#     __tablename__ = "addresses"
#     id: Mapped[int] = mapped_column(primary_key=True)
#     user_id: Mapped[int] = mapped_column(ForeignKey("users.id"))
#     street: Mapped[str]
#
#     user: Mapped["User"] = relationship(back_populates="addresses")
#
#     def __repr__(self):
#         return f"<Address(id={self.id}, street='{self.street}')>"
#
# # To create tables in the database (using the ORM's metadata):
# # Base.metadata.create_all(engine)
# ```
#
# #### b. Session
#
# The `Session` is the most crucial component of the ORM. It represents a "conversation" with the database.
# *   **Unit of Work:** The `Session` tracks all changes (adds, updates, deletes) to objects within its scope. These changes are not sent to the database immediately but are batched together and committed in a single transaction when `session.commit()` is called. If an error occurs, `session.rollback()` can revert all changes.
# *   **Identity Map:** For a given `Session`, if you query for the same database row multiple times, you will always get back the *exact same Python object instance*. This prevents conflicting representations of the same data and ensures object identity within a session.
# *   **Lazy Loading:** When you access a related object (e.g., `user.addresses`), if it hasn't been loaded yet, the `Session` will automatically issue a new SQL query to fetch it from the database.
# *   **Transaction Management:** The `Session` typically operates within a database transaction.
#
# **How it works:**
# 1.  You create a `sessionmaker` bound to your `Engine`.
# 2.  You get a `Session` instance from the `sessionmaker`.
# 3.  You add, query, modify, or delete objects using the `Session`.
# 4.  You call `session.commit()` to persist changes or `session.rollback()` to discard them.
# 5.  It's best practice to use the `Session` as a context manager (`with Session() as session:`), which ensures `commit()` or `rollback()` is called and the session is closed.
#
# ```python
# from sqlalchemy.orm import sessionmaker
#
# # Create tables if they don't exist
# Base.metadata.create_all(engine)
#
# # Create a session factory
# Session = sessionmaker(bind=engine)
#
# # --- ORM Workflow ---
# with Session() as session:
#     # 1. Create objects
#     new_user = User(name="Bob", email="bob@example.com")
#     new_address = Address(street="123 Main St", user=new_user) # Relationship assignment
#
#     # 2. Add objects to the session (they are now "pending")
#     session.add(new_user)
#     session.add(new_address)
#
#     # 3. Commit changes (flushes to DB, starts/ends transaction)
#     session.commit()
#     print(f"Added user: {new_user.id} and address: {new_address.id}")
#
# with Session() as session:
#     # 4. Query objects
#     user_from_db = session.query(User).filter_by(name="Bob").first()
#     # Or for modern SQLAlchemy:
#     # user_from_db = session.scalar(select(User).where(User.name == "Bob"))
#
#     if user_from_db:
#         print(f"Found user: {user_from_db}")
#         print(f"User's addresses: {user_from_db.addresses}") # Lazy loading happens here if not loaded
#
#         # 5. Modify an object
#         user_from_db.email = "bob.smith@example.com"
#
#         # 6. Delete an object (if you want to)
#         # session.delete(user_from_db)
#
#         session.commit() # Persist modification/deletion
#         print(f"Updated user email: {user_from_db.email}")
# ```
#
# ---
#
# ### Summary of How it Works:
#
# 1.  **Configuration:** You define an `Engine` to connect to your specific database.
# 2.  **Schema Definition:** You define your database tables either directly with `MetaData` and `Table` (Core) or by mapping Python classes with `declarative_base()` and `Mapped` (ORM).
# 3.  **SQL Generation (Core):** When using Core, you build SQL statements programmatically using `select()`, `insert()`, etc., which are then executed via a `Connection`.
# 4.  **Object-Relational Mapping (ORM):** When using the ORM:
#     *   You interact with Python objects that represent database rows.
#     *   The `Session` tracks changes to these objects.
#     *   When you `commit()`, the `Session` translates your object-level operations (e.g., `user.name = "New Name"`) into appropriate SQL `UPDATE`, `INSERT`, `DELETE` statements.
#     *   It then executes these SQL statements against the database using the `Engine` and `Connection` in a transaction.
#     *   When you query, SQLAlchemy executes `SELECT` statements, retrieves the raw data, and instantiates Python objects, populating them with the retrieved data.
#
# SQLAlchemy's design makes it incredibly flexible and powerful, suitable for everything from simple scripts to large, complex enterprise applications.
