# %% [markdown]
# ##### Load Env Variable

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
res=llm.invoke("whho is pm of india")
print(res.content)
# Out:
# The current Prime Minister of India is **Narendra Modi**.
#
# He has been serving since 2014 and is a member of the Bharatiya Janata Party (BJP).
